# %% [markdown]
# # Generate Population from National Transport Survey Data
#
# Generate caveat schedules and attributes inputs from UK NTS data.
#
# Provided example uses toy data. You can access the real [UK travel survey from 2002-2021](https://beta.ukdataservice.ac.uk/datacatalogue/studies/study?id=5340) from the [UK Data Service](https://beta.ukdataservice.ac.uk).

# %%
from pathlib import Path

import pandas as pd
from pam import read
from pam.core import Population
from pam.utils import datetime_to_matsim_time

from caveat.evaluate.describe.times import (
    joint_time_distributions_plot,
    times_distributions_plot,
)
from caveat.evaluate.describe.transitions import sequence_prob_plot

# %%
# dir = Path("data/dummyNTS/")
# trips_csv = dir / "trips.tab"
# attributes_csv = dir / "individuals.tab"
# hhs_csv = dir / "households.tab"

dir = Path("C:/Users/fred/Data/UKDA-5340-tab/tab")
trips_csv = dir / "trip_eul_2002-2022.tab"
attributes_csv = dir / "individual_eul_2002-2022.tab"
hhs_csv = dir / "household_eul_2002-2022.tab"

years = [2021]

write_dir = Path("tmp")
write_dir.mkdir(exist_ok=True)
schedules_path = write_dir / "nts_schedules.csv"
attributes_path = write_dir / "nts_attributes.csv"
home_schedules_path = write_dir / "nts_home_schedules.csv"
home_attributes_path = write_dir / "nts_home_attributes.csv"

# %%
travel_diaries = pd.read_csv(
    trips_csv,
    sep="\t",
    usecols=[
        "TripID",
        "JourSeq",
        "DayID",
        "IndividualID",
        "HouseholdID",
        "MainMode_B04ID",
        "TripPurpFrom_B01ID",
        "TripPurpTo_B01ID",
        "TripStart",
        "TripEnd",
        "TripOrigGOR_B02ID",
        "TripDestGOR_B02ID",
        "W5",
        "SurveyYear",
    ],
)
travel_diaries = travel_diaries.rename(
    columns={
        "TripID": "tid",
        "JourSeq": "seq",
        "DayID": "day",
        "IndividualID": "iid",
        "HouseholdID": "hid",
        "TripOrigGOR_B02ID": "ozone",
        "TripDestGOR_B02ID": "dzone",
        "TripPurpFrom_B01ID": "oact",
        "TripPurpTo_B01ID": "dact",
        "MainMode_B04ID": "mode",
        "TripStart": "tst",
        "TripEnd": "tet",
        "W5": "freq",
        "SurveyYear": "year",
    }
)

travel_diaries = travel_diaries[travel_diaries.year.isin(years)]

travel_diaries.tst = pd.to_numeric(travel_diaries.tst, errors="coerce")
travel_diaries.tet = pd.to_numeric(travel_diaries.tet, errors="coerce")
travel_diaries.ozone = pd.to_numeric(travel_diaries.ozone, errors="coerce")
travel_diaries.dzone = pd.to_numeric(travel_diaries.dzone, errors="coerce")
travel_diaries.freq = pd.to_numeric(travel_diaries.freq, errors="coerce")

travel_diaries["did"] = travel_diaries.groupby("iid")["day"].transform(
    lambda x: pd.factorize(x)[0] + 1
)
travel_diaries["pid"] = [
    f"{i}-{d}" for i, d in zip(travel_diaries.iid, travel_diaries.did)
]

travel_diaries = travel_diaries.loc[
    travel_diaries.groupby("pid")
    .filter(lambda x: pd.isnull(x).sum().sum() < 1)
    .index
]
# travel_diaries.freq = travel_diaries.freq / travel_diaries.groupby("iid").day.transform("nunique")
travel_diaries.loc[travel_diaries.tet == 0, "tet"] = 1440

travel_diaries = travel_diaries.drop(["tid", "day", "year", "did"], axis=1)

mode_mapping = {
    1: "walk",
    2: "bike",
    3: "car",  #'Car/van driver'
    4: "car",  #'Car/van driver'
    5: "car",  #'Motorcycle',
    6: "car",  #'Other private transport',
    7: "pt",  # Bus in London',
    8: "pt",  #'Other local bus',
    9: "pt",  #'Non-local bus',
    10: "pt",  #'London Underground',
    11: "pt",  #'Surface Rail',
    12: "car",  #'Taxi/minicab',
    13: "pt",  #'Other public transport',
    -10: "DEAD",
    -8: "NA",
}

purp_mapping = {
    1: "work",
    2: "work",  #'In course of work',
    3: "education",
    4: "shop",  #'Food shopping',
    5: "shop",  #'Non food shopping',
    6: "medical",  #'Personal business medical',
    7: "other",  #'Personal business eat/drink',
    8: "other",  #'Personal business other',
    9: "other",  #'Eat/drink with friends',
    10: "visit",  #'Visit friends',
    11: "other",  #'Other social',
    12: "other",  #'Entertain/ public activity',
    13: "other",  #'Sport: participate',
    14: "home",  #'Holiday: base',
    15: "other",  #'Day trip/just walk',
    16: "other",  #'Other non-escort',
    17: "escort",  #'Escort home',
    18: "escort",  #'Escort work',
    19: "escort",  #'Escort in course of work',
    20: "escort",  #'Escort education',
    21: "escort",  #'Escort shopping/personal business',
    22: "escort",  #'Other escort',
    23: "home",  #'Home',
    -10: "DEAD",
    -8: "NA",
}

travel_diaries["mode"] = travel_diaries["mode"].map(mode_mapping)
travel_diaries["oact"] = travel_diaries["oact"].map(purp_mapping)
travel_diaries["dact"] = travel_diaries["dact"].map(purp_mapping)
travel_diaries.tst = travel_diaries.tst.astype(int)
travel_diaries.tet = travel_diaries.tet.astype(int)

travel_diaries.head(20)
# Out:
#                 iid         hid  seq  mode     oact       dact   tst   tet  \
# 4937043  2021000300  2021000119    2   car     work       home   960   967
# 4937044  2021000300  2021000119    1   car     home       work   473   480
# 4937045  2021000300  2021000119    2   car     work       home   960   967
# 4937046  2021000300  2021000119    1    pt     home    medical   600   612
# 4937047  2021000300  2021000119    2    pt  medical       home   660   672
# 4937048  2021000300  2021000119    1   car     home       shop   690   695
# 4937049  2021000300  2021000119    2   car     shop       home   735   740
# 4937050  2021000301  2021000119    1   car     home       work  1060  1080
# 4937051  2021000301  2021000119    1   car     work       home   360   380
# 4937052  2021000101  2021000039    1   car     home       work   400   420
# 4937053  2021000101  2021000039    2   car     work       home   840   860
# 4937054  2021000101  2021000039    1   car     home       shop   630   638
# 4937055  2021000101  2021000039    2   car     shop       home   665   673
# 4937056  2021000101  2021000039    3  walk     home      other   780   800
# 4937057  2021000101  2021000039    4  walk    other       home   800   820
# 4937058  2021000101  2021000039    1   car     home       work   400   420
# 4937059  2021000101  2021000039    2   car     work       home   840   860
# 4937060  2021000102  2021000039    1   car     home       shop   630   638
# 4937061  2021000102  2021000039    2   car     shop       home   665   673
# 4937062  2021000103  2021000039    1  walk     home  education   490   510
#
#          ozone  dzone      freq           pid
# 4937043      1    1.0  0.341178  2021000300-1
# 4937044      1    1.0  0.341178  2021000300-2
# 4937045      1    1.0  0.341178  2021000300-2
# 4937046      1    1.0  0.451064  2021000300-3
# 4937047      1    1.0  0.451064  2021000300-3
# 4937048      1    1.0  0.431796  2021000300-4
# 4937049      1    1.0  0.431796  2021000300-4
# 4937050      1    1.0  0.341178  2021000301-1
# 4937051      1    1.0  0.364902  2021000301-2
# 4937052      1    1.0  0.393185  2021000101-1
# 4937053      1    1.0  0.393185  2021000101-1
# 4937054      1    1.0  0.488909  2021000101-2
# 4937055      1    1.0  0.488909  2021000101-2
# 4937056      1    1.0  0.426136  2021000101-2
# 4937057      1    1.0  0.426136  2021000101-2
# 4937058      1    1.0  0.393185  2021000101-3
# 4937059      1    1.0  0.393185  2021000101-3
# 4937060      1    1.0  0.488909  2021000102-1
# 4937061      1    1.0  0.488909  2021000102-1
# 4937062      1    1.0  0.393185  2021000103-1

# %%
columns = {
    "SurveyYear": "year",
    "IndividualID": "iid",
    "HouseholdID": "hid",
    "Age_B01ID": "age",
    "Sex_B01ID": "gender",
    "EdAttn1_B01ID": "education",
    "DrivLic_B02ID": "license",
    "CarAccess_B01ID": "car_access",
    "EcoStat_B02ID": "work_status",
    "EthGroupTS_B02ID": "ethnicity",
}
attributes = pd.read_csv(
    attributes_csv, sep="\t", usecols=columns.keys()
).rename(columns=columns)

attributes = attributes[attributes.year.isin(years)]
attributes = attributes[attributes.iid.isin(travel_diaries.iid)]

# expand attributes to days and add pid
pid_to_iid = travel_diaries.set_index("pid")["iid"].to_dict()
expanded_attributes = []
for k, v in pid_to_iid.items():
    expanded_attributes.append(attributes[attributes.iid == v].assign(pid=k))
expanded_attributes = pd.concat(expanded_attributes)
assert set(expanded_attributes.pid) == set(travel_diaries.pid)

# fix special values to zero (DEAD, NULL, NA, etc)
for c in [
    "age",
    "gender",
    "education",
    "license",
    "car_access",
    "work_status",
    "ethnicity",
]:
    expanded_attributes.loc[expanded_attributes[c] < 0, c] = 0
    expanded_attributes.loc[expanded_attributes[c].isnull(), c] = 0

expanded_attributes.head()
# Out:
#                iid         hid  age  gender  ethnicity  education  license  \
# 365774  2021000300  2021000119   15       2          1          1        1
# 365774  2021000300  2021000119   15       2          1          1        1
# 365774  2021000300  2021000119   15       2          1          1        1
# 365774  2021000300  2021000119   15       2          1          1        1
# 365775  2021000301  2021000119   15       1          1          1        1
#
#         car_access  work_status  year           pid
# 365774           3            1  2021  2021000300-1
# 365774           3            1  2021  2021000300-2
# 365774           3            1  2021  2021000300-3
# 365774           3            1  2021  2021000300-4
# 365775           2            1  2021  2021000301-1

# %%
# additionally extract attributes from household table
# add them to individual table for simplicity
columns = {
    "HouseholdID": "hid",
    "Settlement2011EW_B04ID": "area",
    "SurveyYear": "year",
    "HHIncQISEngTS_B01ID": "income",
    "HHoldNumPeople": "hh_size",
    "HHoldStruct_B02ID": "hh_composition",
    "HHoldNumChildren": "hh_children",
    "NumCar": "hh_cars",
    "NumBike": "hh_bikes",
    "NumMCycle": "hh_motorcycles",
}
hhs = pd.read_csv(hhs_csv, sep="\t", usecols=columns.keys()).rename(
    columns=columns
)
hhs = hhs[hhs.year.isin(years)]

# add hh attributes to individuals
for c in [
    "area",
    "income",
    "hh_size",
    "hh_composition",
    "hh_children",
    "hh_cars",
    "hh_bikes",
    "hh_motorcycles",
]:
    mapper = hhs.set_index("hid")[c].to_dict()
    expanded_attributes[c] = expanded_attributes.hid.map(mapper)

for c in [
    "area",
    "income",
    "hh_size",
    "hh_composition",
    "hh_children",
    "hh_cars",
    "hh_bikes",
    "hh_motorcycles",
]:
    expanded_attributes.loc[expanded_attributes[c] < 0, c] = 0
    expanded_attributes.loc[expanded_attributes[c].isnull(), c] = 0

expanded_attributes.drop("hid", axis=1, inplace=True)

expanded_attributes.head()
# Out:
#                iid  age  gender  ethnicity  education  license  car_access  \
# 365774  2021000300   15       2          1          1        1           3
# 365774  2021000300   15       2          1          1        1           3
# 365774  2021000300   15       2          1          1        1           3
# 365774  2021000300   15       2          1          1        1           3
# 365775  2021000301   15       1          1          1        1           2
#
#         work_status  year           pid  area  income  hh_size  \
# 365774            1  2021  2021000300-1     1       4        2
# 365774            1  2021  2021000300-2     1       4        2
# 365774            1  2021  2021000300-3     1       4        2
# 365774            1  2021  2021000300-4     1       4        2
# 365775            1  2021  2021000301-1     1       4        2
#
#         hh_composition  hh_children  hh_cars  hh_bikes  hh_motorcycles
# 365774               2            0      1.0         0             0.0
# 365774               2            0      1.0         0             0.0
# 365774               2            0      1.0         0             0.0
# 365774               2            0      1.0         0             0.0
# 365775               2            0      1.0         0             0.0

# %%
age_mapping = {
    1: 0,
    2: 1,
    3: 3,
    4: 5,
    5: 11,
    6: 16,
    7: 17,
    8: 18,
    9: 19,
    10: 20,
    11: 21,
    12: 26,
    13: 30,
    14: 40,
    15: 50,
    16: 60,
    17: 65,
    18: 70,
    19: 75,
    20: 80,
    21: 85,
}
gender_mapping = {0: "unknown", 1: "M", 2: "F"}
education_mapping = {0: "unknown", 1: "Y", 2: "N"}
license_mapping = {0: "unknown", 1: "yes", 2: "yes", 3: "no"}
car_access_mapping = {
    0: "unknown",
    1: "yes",
    2: "yes",
    3: "yes",
    4: "yes",
    5: "no",
    6: "no",
}
# work_status_mapping = {
#     0: "unknown",
#     1: "FT",
#     2: "PT",
#     3: "unemployed",
#     4: "retired",
#     5: "student",
#     6: "other",
# }
work_status_mapping = {
    0: "unemployed",
    1: "employed",
    2: "employed",
    3: "unemployed",
    4: "unemployed",
    5: "student",
    6: "unemployed",
}
area_mapping = {
    0: "unknown",
    1: "suburban",
    2: "urban",
    3: "rural",
    4: "rural",
    5: "scotland",
}
ethnicity_mapping = {0: "unknown", 1: "white", 2: "non-white"}
hh_composition_mapping = {
    0: "unknown",
    1: "1adult",
    2: "2adults",
    3: "3+adults",
    4: "single_parent",
    5: "2adult_1+child",
    6: "3+adult_1+child",
}
mappings = {
    "age": age_mapping,
    "gender": gender_mapping,
    "education": education_mapping,
    "license": license_mapping,
    "car_access": car_access_mapping,
    "work_status": work_status_mapping,
    "area": area_mapping,
    "ethnicity": ethnicity_mapping,
    "hh_composition": hh_composition_mapping,
}

for c, mapping in mappings.items():
    if c in expanded_attributes.columns:
        expanded_attributes[c] = expanded_attributes[c].map(mapping)

# %%
pam_population = read.load_travel_diary(
    trips=travel_diaries,
    persons_attributes=expanded_attributes,
    trip_freq_as_person_freq=True,
)
print(pam_population.stats)
pam_population.fix_plans()
print(pam_population.stats)
pam_population.random_person().plot()
# Out:
# Using from-to activity parser using 'oact' and 'dact' columns
# Adding pid->hh mapping to persons_attributes from trips.
#
#         Unable to load household area ('hzone') - not found in trips_diary or unable to build from attributes.
#         Pam will try to infer home location from activities, but this behaviour is not recommended.
#
# Using freq of 'None' for all trips.
#  Person pid:2021000036-2 hid:2021000014 plan does not start with 'home' activity: work
#  Person pid:2021000036-3 hid:2021000014 plan does not start with 'home' activity: work
#  Person pid:2021000036-4 hid:2021000014 plan does not start with 'home' activity: work
#  Person pid:2021000061-3 hid:2021000024 plan does not start with 'home' activity: visit
#  Person pid:2021000065-5 hid:2021000026 plan does not start with 'home' activity: work
#  Person pid:2021000065-6 hid:2021000026 plan does not start with 'home' activity: work
#  Person pid:2021000087-2 hid:2021000033 plan does not start with 'home' activity: work
#  Person pid:2021000177-1 hid:2021000066 plan does not start with 'home' activity: work
#  Person pid:2021000177-2 hid:2021000066 plan does not start with 'home' activity: work
#  Person pid:2021000177-3 hid:2021000066 plan does not start with 'home' activity: visit
#  Person pid:2021000184-5 hid:2021000072 plan does not start with 'home' activity: work
#  Person pid:2021000224-1 hid:2021000090 plan does not start with 'home' activity: work
#  Person pid:2021000224-2 hid:2021000090 plan does not start with 'home' activity: work
#  Person pid:2021000224-3 hid:2021000090 plan does not start with 'home' activity: work
#  Person pid:2021000224-5 hid:2021000090 plan does not start with 'home' activity: work
#  Person pid:2021000224-6 hid:2021000090 plan does not start with 'home' activity: work
#  Person pid:2021000248-2 hid:2021000101 plan does not start with 'home' activity: work
#  Person pid:2021000248-6 hid:2021000101 plan does not start with 'home' activity: work
#  Person pid:2021000248-7 hid:2021000101 plan does not start with 'home' activity: work
#  Person pid:2021000269-6 hid:2021000108 plan does not start with 'home' activity: visit
#  Person pid:2021000277-1 hid:2021000111 plan does not start with 'home' activity: visit
#  Person pid:2021000277-3 hid:2021000111 plan does not start with 'home' activity: visit
#  Person pid:2021000277-5 hid:2021000111 plan does not start with 'home' activity: visit
#  Person pid:2021000288-2 hid:2021000114 plan does not start with 'home' activity: escort
#  Person pid:2021000301-2 hid:2021000119 plan does not start with 'home' activity: work
#  Person pid:2021000301-4 hid:2021000119 plan does not start with 'home' activity: work
#  Person pid:2021000306-2 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000306-3 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000306-4 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000306-5 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000307-2 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000307-3 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000307-4 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000307-5 hid:2021000121 plan does not start with 'home' activity: education
#  Person pid:2021000308-3 hid:2021000122 plan does not start with 'home' activity: work
#  Person pid:2021000314-4 hid:2021000124 plan does not start with 'home' activity: work
#  Person pid:2021000351-5 hid:2021000142 plan does not start with 'home' activity: medical
#  Person pid:2021000364-1 hid:2021000148 plan does not start with 'home' activity: medical
#  Person pid:2021000386-4 hid:2021000157 plan does not start with 'home' activity: visit
#  Person pid:2021000410-2 hid:2021000170 plan does not start with 'home' activity: work
#  Person pid:2021000449-4 hid:2021000186 plan does not start with 'home' activity: visit
#  Person pid:2021000450-1 hid:2021000186 plan does not start with 'home' activity: work
#  Person pid:2021000450-2 hid:2021000186 plan does not start with 'home' activity: work
#  Person pid:2021000450-3 hid:2021000186 plan does not start with 'home' activity: work
#  Person pid:2021000450-5 hid:2021000186 plan does not start with 'home' activity: work
#  Person pid:2021000450-6 hid:2021000186 plan does not start with 'home' activity: work
#  Person pid:2021000468-2 hid:2021000193 plan does not start with 'home' activity: other
#  Person pid:2021000496-2 hid:2021000202 plan does not start with 'home' activity: work
#  Person pid:2021000496-3 hid:2021000202 plan does not start with 'home' activity: work
#  Person pid:2021000496-4 hid:2021000202 plan does not start with 'home' activity: work
#  Person pid:2021000496-5 hid:2021000202 plan does not start with 'home' activity: work
#  Person pid:2021000496-6 hid:2021000202 plan does not start with 'home' activity: work
#  Person pid:2021000496-7 hid:2021000202 plan does not start with 'home' activity: work
#  Person pid:2021000561-3 hid:2021000228 plan does not start with 'home' activity: visit
#  Person pid:2021000566-3 hid:2021000230 plan does not start with 'home' activity: work
#  Person pid:2021000566-4 hid:2021000230 plan does not start with 'home' activity: work
#  Person pid:2021000572-2 hid:2021000233 plan does not start with 'home' activity: visit
#  Person pid:2021000581-4 hid:2021000238 plan does not start with 'home' activity: work
#  Person pid:2021000581-6 hid:2021000238 plan does not start with 'home' activity: work
#  Person pid:2021000611-1 hid:2021000251 plan does not start with 'home' activity: work
#  Person pid:2021000615-5 hid:2021000253 plan does not start with 'home' activity: work
#  Person pid:2021000615-6 hid:2021000253 plan does not start with 'home' activity: work
#  Person pid:2021000615-7 hid:2021000253 plan does not start with 'home' activity: work
#  Person pid:2021000619-3 hid:2021000255 plan does not start with 'home' activity: shop
#  Person pid:2021000636-2 hid:2021000260 plan does not start with 'home' activity: other
#  Person pid:2021000636-3 hid:2021000260 plan does not start with 'home' activity: other
#  Person pid:2021000636-4 hid:2021000260 plan does not start with 'home' activity: other
#  Person pid:2021000636-5 hid:2021000260 plan does not start with 'home' activity: other
#  Person pid:2021000650-4 hid:2021000267 plan does not start with 'home' activity: work
#  Person pid:2021000650-5 hid:2021000267 plan does not start with 'home' activity: work
#  Person pid:2021000667-1 hid:2021000275 plan does not start with 'home' activity: work
#  Person pid:2021000667-6 hid:2021000275 plan does not start with 'home' activity: work
#  Person pid:2021000676-3 hid:2021000279 plan does not start with 'home' activity: visit
#  Person pid:2021000697-5 hid:2021000290 plan does not start with 'home' activity: shop
#  Person pid:2021000714-2 hid:2021000297 plan does not start with 'home' activity: visit
#  Person pid:2021000724-3 hid:2021000301 plan does not start with 'home' activity: work
#  Person pid:2021000801-1 hid:2021000329 plan does not start with 'home' activity: work
#  Person pid:2021000801-2 hid:2021000329 plan does not start with 'home' activity: work
#  Person pid:2021000801-3 hid:2021000329 plan does not start with 'home' activity: work
#  Person pid:2021000831-3 hid:2021000341 plan does not start with 'home' activity: shop
#  Person pid:2021000854-4 hid:2021000352 plan does not start with 'home' activity: medical
#  Person pid:2021000901-1 hid:2021000374 plan does not start with 'home' activity: other
#  Person pid:2021000952-2 hid:2021000399 plan does not start with 'home' activity: medical
#  Person pid:2021000952-3 hid:2021000399 plan does not start with 'home' activity: shop
#  Person pid:2021000969-2 hid:2021000407 plan does not start with 'home' activity: visit
#  Person pid:2021000970-2 hid:2021000407 plan does not start with 'home' activity: visit
#  Person pid:2021000990-1 hid:2021000418 plan does not start with 'home' activity: work
#  Person pid:2021001000-1 hid:2021000424 plan does not start with 'home' activity: shop
#  Person pid:2021001000-2 hid:2021000424 plan does not start with 'home' activity: shop
#  Person pid:2021001045-2 hid:2021000440 plan does not start with 'home' activity: shop
#  Person pid:2021001083-4 hid:2021000452 plan does not start with 'home' activity: visit
#  Person pid:2021001100-2 hid:2021000461 plan does not start with 'home' activity: work
#  Person pid:2021001100-3 hid:2021000461 plan does not start with 'home' activity: work
#  Person pid:2021001100-4 hid:2021000461 plan does not start with 'home' activity: work
#  Person pid:2021001100-5 hid:2021000461 plan does not start with 'home' activity: work
#  Person pid:2021001100-6 hid:2021000461 plan does not start with 'home' activity: work
#  Person pid:2021001145-2 hid:2021000481 plan does not start with 'home' activity: other
#  Person pid:2021001170-4 hid:2021000495 plan does not start with 'home' activity: work
#  Person pid:2021001171-4 hid:2021000495 plan does not start with 'home' activity: visit
#  Person pid:2021001172-3 hid:2021000495 plan does not start with 'home' activity: visit
#  Person pid:2021001172-5 hid:2021000495 plan does not start with 'home' activity: visit
#  Person pid:2021001175-2 hid:2021000497 plan does not start with 'home' activity: work
#  Person pid:2021001175-3 hid:2021000497 plan does not start with 'home' activity: work
#  Person pid:2021001175-4 hid:2021000497 plan does not start with 'home' activity: work
#  Person pid:2021001175-6 hid:2021000497 plan does not start with 'home' activity: work
#  Person pid:2021001202-2 hid:2021000510 plan does not start with 'home' activity: other
#  Person pid:2021001203-5 hid:2021000510 plan does not start with 'home' activity: other
#  Person pid:2021001204-5 hid:2021000510 plan does not start with 'home' activity: other
#  Person pid:2021001210-3 hid:2021000514 plan does not start with 'home' activity: work
#  Person pid:2021001210-4 hid:2021000514 plan does not start with 'home' activity: work
#  Person pid:2021001210-5 hid:2021000514 plan does not start with 'home' activity: work
#  Person pid:2021001210-6 hid:2021000514 plan does not start with 'home' activity: work
#  Person pid:2021001241-2 hid:2021000527 plan does not start with 'home' activity: visit
#  Person pid:2021001241-4 hid:2021000527 plan does not start with 'home' activity: visit
#  Person pid:2021001246-6 hid:2021000528 plan does not start with 'home' activity: visit
#  Person pid:2021001279-2 hid:2021000539 plan does not start with 'home' activity: visit
#  Person pid:2021001298-4 hid:2021000547 plan does not start with 'home' activity: visit
#  Person pid:2021001298-6 hid:2021000547 plan does not start with 'home' activity: visit
#  Person pid:2021001316-7 hid:2021000555 plan does not start with 'home' activity: education
#  Person pid:2021001317-7 hid:2021000555 plan does not start with 'home' activity: education
#  Person pid:2021001318-7 hid:2021000555 plan does not start with 'home' activity: education
#  Person pid:2021001319-7 hid:2021000555 plan does not start with 'home' activity: education
#  Person pid:2021001314-4 hid:2021000555 plan does not start with 'home' activity: work
#  Person pid:2021001314-5 hid:2021000555 plan does not start with 'home' activity: work
#  Person pid:2021001314-6 hid:2021000555 plan does not start with 'home' activity: work
#  Person pid:2021001314-7 hid:2021000555 plan does not start with 'home' activity: work
#  Person pid:2021001321-3 hid:2021000556 plan does not start with 'home' activity: shop
#  Person pid:2021001344-3 hid:2021000568 plan does not start with 'home' activity: work
#  Person pid:2021001344-4 hid:2021000568 plan does not start with 'home' activity: work
#  Person pid:2021001344-5 hid:2021000568 plan does not start with 'home' activity: work
#  Person pid:2021001344-6 hid:2021000568 plan does not start with 'home' activity: work
#  Person pid:2021001362-2 hid:2021000573 plan does not start with 'home' activity: work
#  Person pid:2021001362-3 hid:2021000573 plan does not start with 'home' activity: work
#  Person pid:2021001364-2 hid:2021000574 plan does not start with 'home' activity: shop
#  Person pid:2021001367-2 hid:2021000575 plan does not start with 'home' activity: work
#  Person pid:2021001367-3 hid:2021000575 plan does not start with 'home' activity: work
#  Person pid:2021001367-5 hid:2021000575 plan does not start with 'home' activity: work
#  Person pid:2021001367-6 hid:2021000575 plan does not start with 'home' activity: work
#  Person pid:2021001372-2 hid:2021000577 plan does not start with 'home' activity: work
#  Person pid:2021001375-2 hid:2021000578 plan does not start with 'home' activity: visit
#  Person pid:2021001386-2 hid:2021000583 plan does not start with 'home' activity: work
#  Person pid:2021001386-5 hid:2021000583 plan does not start with 'home' activity: work
#  Person pid:2021001386-6 hid:2021000583 plan does not start with 'home' activity: work
#  Person pid:2021001387-5 hid:2021000583 plan does not start with 'home' activity: work
#  Person pid:2021001406-3 hid:2021000591 plan does not start with 'home' activity: work
#  Person pid:2021001430-4 hid:2021000600 plan does not start with 'home' activity: visit
#  Person pid:2021001441-2 hid:2021000603 plan does not start with 'home' activity: visit
#  Person pid:2021001441-3 hid:2021000603 plan does not start with 'home' activity: visit
#  Person pid:2021001442-2 hid:2021000603 plan does not start with 'home' activity: visit
#  Person pid:2021001442-3 hid:2021000603 plan does not start with 'home' activity: visit
#  Person pid:2021001460-3 hid:2021000609 plan does not start with 'home' activity: visit
#  Person pid:2021001461-3 hid:2021000609 plan does not start with 'home' activity: visit
#  Person pid:2021001462-3 hid:2021000609 plan does not start with 'home' activity: visit
#  Person pid:2021001468-2 hid:2021000611 plan does not start with 'home' activity: work
#  Person pid:2021001493-3 hid:2021000622 plan does not start with 'home' activity: visit
#  Person pid:2021001494-3 hid:2021000622 plan does not start with 'home' activity: visit
#  Person pid:2021001495-4 hid:2021000623 plan does not start with 'home' activity: work
#  Person pid:2021001495-6 hid:2021000623 plan does not start with 'home' activity: work
#  Person pid:2021001495-7 hid:2021000623 plan does not start with 'home' activity: work
#  Person pid:2021001501-2 hid:2021000627 plan does not start with 'home' activity: shop
#  Person pid:2021001501-3 hid:2021000627 plan does not start with 'home' activity: shop
#  Person pid:2021001591-5 hid:2021000672 plan does not start with 'home' activity: shop
#  Person pid:2021001592-6 hid:2021000672 plan does not start with 'home' activity: shop
#  Person pid:2021001593-6 hid:2021000672 plan does not start with 'home' activity: escort
#  Person pid:2021001644-2 hid:2021000696 plan does not start with 'home' activity: visit
#  Person pid:2021001648-1 hid:2021000699 plan does not start with 'home' activity: work
#  Person pid:2021001648-2 hid:2021000699 plan does not start with 'home' activity: work
#  Person pid:2021001678-2 hid:2021000711 plan does not start with 'home' activity: shop
#  Person pid:2021001684-2 hid:2021000714 plan does not start with 'home' activity: work
#  Person pid:2021001684-3 hid:2021000714 plan does not start with 'home' activity: work
#  Person pid:2021001684-4 hid:2021000714 plan does not start with 'home' activity: work
#  Person pid:2021001684-5 hid:2021000714 plan does not start with 'home' activity: work
#  Person pid:2021001684-6 hid:2021000714 plan does not start with 'home' activity: work
#  Person pid:2021001684-7 hid:2021000714 plan does not start with 'home' activity: work
#  Person pid:2021001698-1 hid:2021000718 plan does not start with 'home' activity: visit
#  Person pid:2021001707-5 hid:2021000725 plan does not start with 'home' activity: work
#  Person pid:2021001707-6 hid:2021000725 plan does not start with 'home' activity: work
#  Person pid:2021001742-3 hid:2021000742 plan does not start with 'home' activity: work
#  Person pid:2021001743-2 hid:2021000742 plan does not start with 'home' activity: work
#  Person pid:2021001743-4 hid:2021000742 plan does not start with 'home' activity: work
#  Person pid:2021001743-5 hid:2021000742 plan does not start with 'home' activity: work
#  Person pid:2021001750-1 hid:2021000745 plan does not start with 'home' activity: work
#  Person pid:2021001750-2 hid:2021000745 plan does not start with 'home' activity: work
#  Person pid:2021001773-2 hid:2021000756 plan does not start with 'home' activity: escort
#  Person pid:2021001803-5 hid:2021000765 plan does not start with 'home' activity: work
#  Person pid:2021001826-3 hid:2021000772 plan does not start with 'home' activity: visit
#  Person pid:2021001834-6 hid:2021000775 plan does not start with 'home' activity: visit
#  Person pid:2021001834-7 hid:2021000775 plan does not start with 'home' activity: visit
#  Person pid:2021001853-1 hid:2021000781 plan does not start with 'home' activity: work
#  Person pid:2021001853-5 hid:2021000781 plan does not start with 'home' activity: work
#  Person pid:2021001853-7 hid:2021000781 plan does not start with 'home' activity: work
#  Person pid:2021001880-4 hid:2021000793 plan does not start with 'home' activity: visit
#  Person pid:2021001880-5 hid:2021000793 plan does not start with 'home' activity: visit
#  Person pid:2021001881-4 hid:2021000793 plan does not start with 'home' activity: visit
#  Person pid:2021001881-5 hid:2021000793 plan does not start with 'home' activity: visit
#  Person pid:2021001906-3 hid:2021000803 plan does not start with 'home' activity: education
#  Person pid:2021001906-4 hid:2021000803 plan does not start with 'home' activity: education
#  Person pid:2021001908-3 hid:2021000804 plan does not start with 'home' activity: work
#  Person pid:2021001923-2 hid:2021000811 plan does not start with 'home' activity: visit
#  Person pid:2021001923-5 hid:2021000811 plan does not start with 'home' activity: visit
#  Person pid:2021001923-6 hid:2021000811 plan does not start with 'home' activity: visit
#  Person pid:2021001923-7 hid:2021000811 plan does not start with 'home' activity: visit
#  Person pid:2021001934-1 hid:2021000815 plan does not start with 'home' activity: escort
#  Person pid:2021001994-1 hid:2021000841 plan does not start with 'home' activity: work
#  Person pid:2021002002-5 hid:2021000844 plan does not start with 'home' activity: visit
#  Person pid:2021002002-7 hid:2021000844 plan does not start with 'home' activity: visit
#  Person pid:2021002003-2 hid:2021000844 plan does not start with 'home' activity: visit
#  Person pid:2021002004-3 hid:2021000844 plan does not start with 'home' activity: other
#  Person pid:2021002017-2 hid:2021000852 plan does not start with 'home' activity: visit
#  Person pid:2021002018-3 hid:2021000852 plan does not start with 'home' activity: visit
#  Person pid:2021002041-2 hid:2021000861 plan does not start with 'home' activity: shop
#  Person pid:2021002068-1 hid:2021000874 plan does not start with 'home' activity: shop
#  Person pid:2021002100-4 hid:2021000885 plan does not start with 'home' activity: visit
#  Person pid:2021002100-5 hid:2021000885 plan does not start with 'home' activity: visit
#  Person pid:2021002101-4 hid:2021000885 plan does not start with 'home' activity: visit
#  Person pid:2021002101-5 hid:2021000885 plan does not start with 'home' activity: visit
#  Person pid:2021002130-2 hid:2021000897 plan does not start with 'home' activity: visit
#  Person pid:2021002142-2 hid:2021000901 plan does not start with 'home' activity: escort
#  Person pid:2021002142-5 hid:2021000901 plan does not start with 'home' activity: escort
#  Person pid:2021002142-6 hid:2021000901 plan does not start with 'home' activity: escort
#  Person pid:2021002144-2 hid:2021000901 plan does not start with 'home' activity: escort
#  Person pid:2021002144-5 hid:2021000901 plan does not start with 'home' activity: escort
#  Person pid:2021002144-6 hid:2021000901 plan does not start with 'home' activity: escort
#  Person pid:2021002171-1 hid:2021000913 plan does not start with 'home' activity: visit
#  Person pid:2021002172-1 hid:2021000913 plan does not start with 'home' activity: visit
#  Person pid:2021002185-2 hid:2021000920 plan does not start with 'home' activity: work
#  Person pid:2021002187-1 hid:2021000921 plan does not start with 'home' activity: escort
#  Person pid:2021002235-6 hid:2021000946 plan does not start with 'home' activity: work
#  Person pid:2021002253-2 hid:2021000954 plan does not start with 'home' activity: work
#  Person pid:2021002253-3 hid:2021000954 plan does not start with 'home' activity: work
#  Person pid:2021002253-4 hid:2021000954 plan does not start with 'home' activity: work
#  Person pid:2021002253-5 hid:2021000954 plan does not start with 'home' activity: work
#  Person pid:2021002269-3 hid:2021000962 plan does not start with 'home' activity: visit
#  Person pid:2021002269-4 hid:2021000962 plan does not start with 'home' activity: visit
#  Person pid:2021002270-2 hid:2021000963 plan does not start with 'home' activity: work
#  Person pid:2021002270-3 hid:2021000963 plan does not start with 'home' activity: work
#  Person pid:2021002270-4 hid:2021000963 plan does not start with 'home' activity: work
#  Person pid:2021002270-5 hid:2021000963 plan does not start with 'home' activity: work
#  Person pid:2021002270-6 hid:2021000963 plan does not start with 'home' activity: work
#  Person pid:2021002270-7 hid:2021000963 plan does not start with 'home' activity: work
#  Person pid:2021002314-3 hid:2021000980 plan does not start with 'home' activity: work
#  Person pid:2021002327-6 hid:2021000987 plan does not start with 'home' activity: visit
#  Person pid:2021002381-3 hid:2021001010 plan does not start with 'home' activity: other
#  Person pid:2021002400-4 hid:2021001019 plan does not start with 'home' activity: visit
#  Person pid:2021002401-3 hid:2021001019 plan does not start with 'home' activity: medical
#  Person pid:2021002470-3 hid:2021001045 plan does not start with 'home' activity: visit
#  Person pid:2021002475-4 hid:2021001047 plan does not start with 'home' activity: education
#  Person pid:2021002475-6 hid:2021001047 plan does not start with 'home' activity: visit
#  Person pid:2021002490-6 hid:2021001056 plan does not start with 'home' activity: work
#  Person pid:2021002525-1 hid:2021001070 plan does not start with 'home' activity: work
#  Person pid:2021002525-3 hid:2021001070 plan does not start with 'home' activity: work
#  Person pid:2021002525-4 hid:2021001070 plan does not start with 'home' activity: work
#  Person pid:2021002529-1 hid:2021001072 plan does not start with 'home' activity: work
#  Person pid:2021002529-2 hid:2021001072 plan does not start with 'home' activity: work
#  Person pid:2021002554-1 hid:2021001080 plan does not start with 'home' activity: work
#  Person pid:2021002554-2 hid:2021001080 plan does not start with 'home' activity: work
#  Person pid:2021002554-3 hid:2021001080 plan does not start with 'home' activity: visit
#  Person pid:2021002554-5 hid:2021001080 plan does not start with 'home' activity: work
#  Person pid:2021002554-6 hid:2021001080 plan does not start with 'home' activity: work
#  Person pid:2021002554-7 hid:2021001080 plan does not start with 'home' activity: work
#  Person pid:2021002559-2 hid:2021001083 plan does not start with 'home' activity: work
#  Person pid:2021002559-3 hid:2021001083 plan does not start with 'home' activity: work
#  Person pid:2021002559-4 hid:2021001083 plan does not start with 'home' activity: work
#  Person pid:2021002577-1 hid:2021001091 plan does not start with 'home' activity: visit
#  Person pid:2021002577-2 hid:2021001091 plan does not start with 'home' activity: visit
#  Person pid:2021002605-1 hid:2021001103 plan does not start with 'home' activity: work
#  Person pid:2021002626-5 hid:2021001115 plan does not start with 'home' activity: visit
#  Person pid:2021002627-6 hid:2021001115 plan does not start with 'home' activity: visit
#  Person pid:2021002628-5 hid:2021001115 plan does not start with 'home' activity: visit
#  Person pid:2021002629-5 hid:2021001115 plan does not start with 'home' activity: visit
#  Person pid:2021002661-4 hid:2021001130 plan does not start with 'home' activity: shop
#  Person pid:2021002662-1 hid:2021001130 plan does not start with 'home' activity: work
#  Person pid:2021002662-5 hid:2021001130 plan does not start with 'home' activity: shop
#  Person pid:2021002696-2 hid:2021001144 plan does not start with 'home' activity: other
#  Person pid:2021002732-2 hid:2021001159 plan does not start with 'home' activity: medical
#  Person pid:2021002733-4 hid:2021001160 plan does not start with 'home' activity: work
#  Person pid:2021002733-5 hid:2021001160 plan does not start with 'home' activity: work
#  Person pid:2021002733-6 hid:2021001160 plan does not start with 'home' activity: work
#  Person pid:2021002737-1 hid:2021001162 plan does not start with 'home' activity: visit
#  Person pid:2021002774-5 hid:2021001179 plan does not start with 'home' activity: shop
#  Person pid:2021002793-1 hid:2021001188 plan does not start with 'home' activity: work
#  Person pid:2021002793-2 hid:2021001188 plan does not start with 'home' activity: work
#  Person pid:2021002793-3 hid:2021001188 plan does not start with 'home' activity: work
#  Person pid:2021002793-4 hid:2021001188 plan does not start with 'home' activity: work
#  Person pid:2021002793-5 hid:2021001188 plan does not start with 'home' activity: work
#  Person pid:2021002805-2 hid:2021001194 plan does not start with 'home' activity: education
#  Person pid:2021002806-2 hid:2021001194 plan does not start with 'home' activity: education
#  Person pid:2021002842-1 hid:2021001211 plan does not start with 'home' activity: work
#  Person pid:2021002842-2 hid:2021001211 plan does not start with 'home' activity: work
#  Person pid:2021002842-3 hid:2021001211 plan does not start with 'home' activity: work
#  Person pid:2021002842-4 hid:2021001211 plan does not start with 'home' activity: work
#  Person pid:2021002842-5 hid:2021001211 plan does not start with 'home' activity: work
#  Person pid:2021002868-3 hid:2021001223 plan does not start with 'home' activity: work
#  Person pid:2021002879-3 hid:2021001228 plan does not start with 'home' activity: visit
#  Person pid:2021002889-2 hid:2021001233 plan does not start with 'home' activity: escort
#  Person pid:2021002890-2 hid:2021001233 plan does not start with 'home' activity: escort
#  Person pid:2021002891-2 hid:2021001233 plan does not start with 'home' activity: other
#  Person pid:2021002921-3 hid:2021001245 plan does not start with 'home' activity: shop
#  Person pid:2021002962-3 hid:2021001259 plan does not start with 'home' activity: work
#  Person pid:2021003034-6 hid:2021001293 plan does not start with 'home' activity: visit
#  Person pid:2021003064-3 hid:2021001307 plan does not start with 'home' activity: visit
#  Person pid:2021003088-7 hid:2021001319 plan does not start with 'home' activity: work
#  Person pid:2021003089-4 hid:2021001319 plan does not start with 'home' activity: visit
#  Person pid:2021003095-1 hid:2021001324 plan does not start with 'home' activity: visit
#  Person pid:2021003095-4 hid:2021001324 plan does not start with 'home' activity: visit
#  Person pid:2021003112-2 hid:2021001333 plan does not start with 'home' activity: work
#  Person pid:2021003112-4 hid:2021001333 plan does not start with 'home' activity: work
#  Person pid:2021003112-5 hid:2021001333 plan does not start with 'home' activity: work
#  Person pid:2021003112-6 hid:2021001333 plan does not start with 'home' activity: work
#  Person pid:2021003127-2 hid:2021001341 plan does not start with 'home' activity: shop
#  Person pid:2021003188-1 hid:2021001363 plan does not start with 'home' activity: visit
#  Person pid:2021003188-5 hid:2021001363 plan does not start with 'home' activity: visit
#  Person pid:2021003189-1 hid:2021001363 plan does not start with 'home' activity: visit
#  Person pid:2021003189-3 hid:2021001363 plan does not start with 'home' activity: visit
#  Person pid:2021003189-5 hid:2021001363 plan does not start with 'home' activity: visit
#  Person pid:2021003190-2 hid:2021001364 plan does not start with 'home' activity: shop
#  Person pid:2021003191-1 hid:2021001364 plan does not start with 'home' activity: escort
#  Person pid:2021003192-2 hid:2021001364 plan does not start with 'home' activity: escort
#  Person pid:2021003210-2 hid:2021001372 plan does not start with 'home' activity: visit
#  Person pid:2021003252-2 hid:2021001393 plan does not start with 'home' activity: visit
#  Person pid:2021003255-2 hid:2021001395 plan does not start with 'home' activity: work
#  Person pid:2021003255-3 hid:2021001395 plan does not start with 'home' activity: work
#  Person pid:2021003271-4 hid:2021001400 plan does not start with 'home' activity: work
#  Person pid:2021003294-4 hid:2021001407 plan does not start with 'home' activity: visit
#  Person pid:2021003295-1 hid:2021001407 plan does not start with 'home' activity: visit
#  Person pid:2021003300-2 hid:2021001409 plan does not start with 'home' activity: visit
#  Person pid:2021003328-2 hid:2021001421 plan does not start with 'home' activity: work
#  Person pid:2021003347-2 hid:2021001429 plan does not start with 'home' activity: work
#  Person pid:2021003366-1 hid:2021001436 plan does not start with 'home' activity: shop
#  Person pid:2021003369-3 hid:2021001437 plan does not start with 'home' activity: work
#  Person pid:2021003369-4 hid:2021001437 plan does not start with 'home' activity: work
#  Person pid:2021003369-6 hid:2021001437 plan does not start with 'home' activity: work
#  Person pid:2021003370-1 hid:2021001438 plan does not start with 'home' activity: visit
#  Person pid:2021003371-1 hid:2021001438 plan does not start with 'home' activity: visit
#  Person pid:2021003372-1 hid:2021001438 plan does not start with 'home' activity: visit
#  Person pid:2021003459-5 hid:2021001473 plan does not start with 'home' activity: visit
#  Person pid:2021003459-6 hid:2021001473 plan does not start with 'home' activity: visit
#  Person pid:2021003459-7 hid:2021001473 plan does not start with 'home' activity: visit
#  Person pid:2021003460-5 hid:2021001473 plan does not start with 'home' activity: visit
#  Person pid:2021003550-2 hid:2021001506 plan does not start with 'home' activity: shop
#  Person pid:2021003551-1 hid:2021001506 plan does not start with 'home' activity: shop
#  Person pid:2021003552-2 hid:2021001507 plan does not start with 'home' activity: other
#  Person pid:2021003600-4 hid:2021001524 plan does not start with 'home' activity: escort
#  Person pid:2021003616-4 hid:2021001534 plan does not start with 'home' activity: work
#  Person pid:2021003637-1 hid:2021001544 plan does not start with 'home' activity: education
#  Person pid:2021003679-3 hid:2021001561 plan does not start with 'home' activity: work
#  Person pid:2021003679-4 hid:2021001561 plan does not start with 'home' activity: work
#  Person pid:2021003679-7 hid:2021001561 plan does not start with 'home' activity: work
#  Person pid:2021003692-1 hid:2021001566 plan does not start with 'home' activity: work
#  Person pid:2021003692-2 hid:2021001566 plan does not start with 'home' activity: work
#  Person pid:2021003692-3 hid:2021001566 plan does not start with 'home' activity: work
#  Person pid:2021003692-5 hid:2021001566 plan does not start with 'home' activity: visit
#  Person pid:2021003698-2 hid:2021001569 plan does not start with 'home' activity: other
#  Person pid:2021003698-3 hid:2021001569 plan does not start with 'home' activity: other
#  Person pid:2021003698-4 hid:2021001569 plan does not start with 'home' activity: other
#  Person pid:2021003700-1 hid:2021001570 plan does not start with 'home' activity: education
#  Person pid:2021003700-7 hid:2021001570 plan does not start with 'home' activity: visit
#  Person pid:2021003703-4 hid:2021001571 plan does not start with 'home' activity: visit
#  Person pid:2021003754-1 hid:2021001591 plan does not start with 'home' activity: education
#  Person pid:2021003754-3 hid:2021001591 plan does not start with 'home' activity: visit
#  Person pid:2021003752-2 hid:2021001591 plan does not start with 'home' activity: visit
#  Person pid:2021003753-3 hid:2021001591 plan does not start with 'home' activity: visit
#  Person pid:2021003753-4 hid:2021001591 plan does not start with 'home' activity: visit
#  Person pid:2021003755-3 hid:2021001592 plan does not start with 'home' activity: work
#  Person pid:2021003755-4 hid:2021001592 plan does not start with 'home' activity: work
#  Person pid:2021003755-5 hid:2021001592 plan does not start with 'home' activity: work
#  Person pid:2021003761-5 hid:2021001596 plan does not start with 'home' activity: visit
#  Person pid:2021003761-7 hid:2021001596 plan does not start with 'home' activity: visit
#  Person pid:2021003791-3 hid:2021001611 plan does not start with 'home' activity: escort
#  Person pid:2021003793-3 hid:2021001611 plan does not start with 'home' activity: education
#  Person pid:2021003794-3 hid:2021001611 plan does not start with 'home' activity: escort
#  Person pid:2021003799-3 hid:2021001614 plan does not start with 'home' activity: work
#  Person pid:2021003799-4 hid:2021001614 plan does not start with 'home' activity: work
#  Person pid:2021003800-3 hid:2021001614 plan does not start with 'home' activity: visit
#  Person pid:2021003804-3 hid:2021001615 plan does not start with 'home' activity: visit
#  Person pid:2021003804-4 hid:2021001615 plan does not start with 'home' activity: visit
#  Person pid:2021003818-1 hid:2021001619 plan does not start with 'home' activity: work
#  Person pid:2021003860-2 hid:2021001632 plan does not start with 'home' activity: escort
#  Person pid:2021003861-6 hid:2021001632 plan does not start with 'home' activity: medical
#  Person pid:2021003875-6 hid:2021001639 plan does not start with 'home' activity: other
#  Person pid:2021003876-3 hid:2021001639 plan does not start with 'home' activity: other
#  Person pid:2021003877-4 hid:2021001639 plan does not start with 'home' activity: other
#  Person pid:2021003878-6 hid:2021001639 plan does not start with 'home' activity: other
#  Person pid:2021003879-6 hid:2021001639 plan does not start with 'home' activity: other
#  Person pid:2021003916-1 hid:2021001657 plan does not start with 'home' activity: visit
#  Person pid:2021003916-2 hid:2021001657 plan does not start with 'home' activity: visit
#  Person pid:2021003917-3 hid:2021001658 plan does not start with 'home' activity: visit
#  Person pid:2021003920-1 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003920-3 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003920-4 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003921-1 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003921-3 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003921-4 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003922-1 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003922-3 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003922-4 hid:2021001659 plan does not start with 'home' activity: education
#  Person pid:2021003924-2 hid:2021001660 plan does not start with 'home' activity: education
#  Person pid:2021003924-3 hid:2021001660 plan does not start with 'home' activity: education
#  Person pid:2021003925-2 hid:2021001660 plan does not start with 'home' activity: education
#  Person pid:2021003925-3 hid:2021001660 plan does not start with 'home' activity: education
#  Person pid:2021003925-4 hid:2021001660 plan does not start with 'home' activity: education
#  Person pid:2021003954-2 hid:2021001675 plan does not start with 'home' activity: work
#  Person pid:2021003954-3 hid:2021001675 plan does not start with 'home' activity: work
#  Person pid:2021003954-4 hid:2021001675 plan does not start with 'home' activity: work
#  Person pid:2021003969-7 hid:2021001681 plan does not start with 'home' activity: work
#  Person pid:2021003970-7 hid:2021001681 plan does not start with 'home' activity: visit
#  Person pid:2021003975-2 hid:2021001684 plan does not start with 'home' activity: escort
#  Person pid:2021003982-3 hid:2021001687 plan does not start with 'home' activity: work
#  Person pid:2021003982-5 hid:2021001687 plan does not start with 'home' activity: work
#  Person pid:2021003982-6 hid:2021001687 plan does not start with 'home' activity: work
#  Person pid:2021003982-7 hid:2021001687 plan does not start with 'home' activity: work
#  Person pid:2021004004-1 hid:2021001698 plan does not start with 'home' activity: visit
#  Person pid:2021004006-2 hid:2021001700 plan does not start with 'home' activity: other
#  Person pid:2021004007-2 hid:2021001700 plan does not start with 'home' activity: other
#  Person pid:2021004010-2 hid:2021001701 plan does not start with 'home' activity: other
#  Person pid:2021004028-1 hid:2021001707 plan does not start with 'home' activity: visit
#  Person pid:2021004028-2 hid:2021001707 plan does not start with 'home' activity: visit
#  Person pid:2021004029-1 hid:2021001707 plan does not start with 'home' activity: visit
#  Person pid:2021004029-2 hid:2021001707 plan does not start with 'home' activity: visit
#  Person pid:2021004042-2 hid:2021001713 plan does not start with 'home' activity: shop
#  Person pid:2021004097-3 hid:2021001743 plan does not start with 'home' activity: work
#  Person pid:2021004119-3 hid:2021001749 plan does not start with 'home' activity: other
#  Person pid:2021004124-1 hid:2021001751 plan does not start with 'home' activity: work
#  Person pid:2021004124-2 hid:2021001751 plan does not start with 'home' activity: work
#  Person pid:2021004124-3 hid:2021001751 plan does not start with 'home' activity: work
#  Person pid:2021004124-6 hid:2021001751 plan does not start with 'home' activity: work
#  Person pid:2021004124-7 hid:2021001751 plan does not start with 'home' activity: work
#  Person pid:2021004129-3 hid:2021001754 plan does not start with 'home' activity: work
#  Person pid:2021004149-7 hid:2021001763 plan does not start with 'home' activity: work
#  Person pid:2021004151-4 hid:2021001763 plan does not start with 'home' activity: visit
#  Person pid:2021004158-3 hid:2021001765 plan does not start with 'home' activity: visit
#  Person pid:2021004158-7 hid:2021001765 plan does not start with 'home' activity: visit
#  Person pid:2021004165-4 hid:2021001767 plan does not start with 'home' activity: visit
#  Person pid:2021004193-5 hid:2021001779 plan does not start with 'home' activity: visit
#  Person pid:2021004194-3 hid:2021001779 plan does not start with 'home' activity: work
#  Person pid:2021004194-4 hid:2021001779 plan does not start with 'home' activity: work
#  Person pid:2021004211-3 hid:2021001787 plan does not start with 'home' activity: work
#  Person pid:2021004227-5 hid:2021001796 plan does not start with 'home' activity: work
#  Person pid:2021004243-6 hid:2021001802 plan does not start with 'home' activity: work
#  Person pid:2021004243-7 hid:2021001802 plan does not start with 'home' activity: work
#  Person pid:2021004256-3 hid:2021001807 plan does not start with 'home' activity: visit
#  Person pid:2021004257-4 hid:2021001807 plan does not start with 'home' activity: education
#  Person pid:2021004257-5 hid:2021001807 plan does not start with 'home' activity: education
#  Person pid:2021004269-2 hid:2021001812 plan does not start with 'home' activity: work
#  Person pid:2021004273-2 hid:2021001814 plan does not start with 'home' activity: visit
#  Person pid:2021004285-3 hid:2021001819 plan does not start with 'home' activity: visit
#  Person pid:2021004286-5 hid:2021001819 plan does not start with 'home' activity: visit
#  Person pid:2021004292-5 hid:2021001822 plan does not start with 'home' activity: work
#  Person pid:2021004298-1 hid:2021001825 plan does not start with 'home' activity: shop
#  Person pid:2021004299-5 hid:2021001826 plan does not start with 'home' activity: visit
#  Person pid:2021004299-6 hid:2021001826 plan does not start with 'home' activity: visit
#  Person pid:2021004312-3 hid:2021001832 plan does not start with 'home' activity: visit
#  Person pid:2021004313-3 hid:2021001832 plan does not start with 'home' activity: visit
#  Person pid:2021004333-2 hid:2021001841 plan does not start with 'home' activity: visit
#  Person pid:2021004333-4 hid:2021001841 plan does not start with 'home' activity: visit
#  Person pid:2021004333-5 hid:2021001841 plan does not start with 'home' activity: visit
#  Person pid:2021004333-6 hid:2021001841 plan does not start with 'home' activity: visit
#  Person pid:2021004343-6 hid:2021001847 plan does not start with 'home' activity: visit
#  Person pid:2021004344-2 hid:2021001847 plan does not start with 'home' activity: visit
#  Person pid:2021004353-2 hid:2021001852 plan does not start with 'home' activity: work
#  Person pid:2021004353-3 hid:2021001852 plan does not start with 'home' activity: work
#  Person pid:2021004353-4 hid:2021001852 plan does not start with 'home' activity: work
#  Person pid:2021004353-7 hid:2021001852 plan does not start with 'home' activity: work
#  Person pid:2021004365-3 hid:2021001857 plan does not start with 'home' activity: visit
#  Person pid:2021004365-5 hid:2021001857 plan does not start with 'home' activity: visit
#  Person pid:2021004408-1 hid:2021001875 plan does not start with 'home' activity: visit
#  Person pid:2021004408-7 hid:2021001875 plan does not start with 'home' activity: visit
#  Person pid:2021004409-1 hid:2021001875 plan does not start with 'home' activity: visit
#  Person pid:2021004417-1 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004417-2 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004417-5 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004417-6 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004417-7 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-1 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-2 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-3 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-4 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-5 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-6 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004418-7 hid:2021001879 plan does not start with 'home' activity: work
#  Person pid:2021004424-3 hid:2021001881 plan does not start with 'home' activity: work
#  Person pid:2021004464-1 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004464-2 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004464-3 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004464-4 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004464-5 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004465-1 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004465-2 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004465-3 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004465-4 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004465-5 hid:2021001897 plan does not start with 'home' activity: education
#  Person pid:2021004486-4 hid:2021001907 plan does not start with 'home' activity: work
#  Person pid:2021004486-5 hid:2021001907 plan does not start with 'home' activity: work
#  Person pid:2021004486-6 hid:2021001907 plan does not start with 'home' activity: visit
#  Person pid:2021004486-7 hid:2021001907 plan does not start with 'home' activity: work
#  Person pid:2021004496-3 hid:2021001912 plan does not start with 'home' activity: work
#  Person pid:2021004496-4 hid:2021001912 plan does not start with 'home' activity: work
#  Person pid:2021004496-5 hid:2021001912 plan does not start with 'home' activity: work
#  Person pid:2021004497-4 hid:2021001912 plan does not start with 'home' activity: education
#  Person pid:2021004498-5 hid:2021001912 plan does not start with 'home' activity: education
#  Person pid:2021004504-3 hid:2021001915 plan does not start with 'home' activity: work
#  Person pid:2021004504-4 hid:2021001915 plan does not start with 'home' activity: work
#  Person pid:2021004504-5 hid:2021001915 plan does not start with 'home' activity: work
#  Person pid:2021004512-1 hid:2021001920 plan does not start with 'home' activity: escort
#  Person pid:2021004514-1 hid:2021001920 plan does not start with 'home' activity: education
#  Person pid:2021004526-4 hid:2021001924 plan does not start with 'home' activity: shop
#  Person pid:2021004532-3 hid:2021001926 plan does not start with 'home' activity: work
#  Person pid:2021004532-4 hid:2021001926 plan does not start with 'home' activity: work
#  Person pid:2021004532-6 hid:2021001926 plan does not start with 'home' activity: work
#  Person pid:2021004549-2 hid:2021001933 plan does not start with 'home' activity: visit
#  Person pid:2021004564-2 hid:2021001941 plan does not start with 'home' activity: visit
#  Person pid:2021004567-3 hid:2021001942 plan does not start with 'home' activity: visit
#  Person pid:2021004568-6 hid:2021001942 plan does not start with 'home' activity: visit
#  Person pid:2021004582-4 hid:2021001949 plan does not start with 'home' activity: visit
#  Person pid:2021004583-2 hid:2021001949 plan does not start with 'home' activity: work
#  Person pid:2021004583-4 hid:2021001949 plan does not start with 'home' activity: work
#  Person pid:2021004583-5 hid:2021001949 plan does not start with 'home' activity: work
#  Person pid:2021004589-4 hid:2021001952 plan does not start with 'home' activity: shop
#  Person pid:2021004590-2 hid:2021001952 plan does not start with 'home' activity: shop
#  Person pid:2021004595-3 hid:2021001955 plan does not start with 'home' activity: work
#  Person pid:2021004595-4 hid:2021001955 plan does not start with 'home' activity: work
#  Person pid:2021004595-5 hid:2021001955 plan does not start with 'home' activity: work
#  Person pid:2021004595-6 hid:2021001955 plan does not start with 'home' activity: work
#  Person pid:2021004630-1 hid:2021001972 plan does not start with 'home' activity: shop
#  Person pid:2021004638-5 hid:2021001974 plan does not start with 'home' activity: other
#  Person pid:2021004638-6 hid:2021001974 plan does not start with 'home' activity: other
#  Person pid:2021004677-3 hid:2021001993 plan does not start with 'home' activity: visit
#  Person pid:2021004678-2 hid:2021001993 plan does not start with 'home' activity: visit
#  Person pid:2021004709-2 hid:2021002007 plan does not start with 'home' activity: escort
#  Person pid:2021004711-2 hid:2021002007 plan does not start with 'home' activity: education
#  Person pid:2021004712-1 hid:2021002007 plan does not start with 'home' activity: education
#  Person pid:2021004750-1 hid:2021002024 plan does not start with 'home' activity: visit
#  Person pid:2021004751-1 hid:2021002024 plan does not start with 'home' activity: visit
#  Person pid:2021004751-2 hid:2021002024 plan does not start with 'home' activity: education
#  Person pid:2021004751-3 hid:2021002024 plan does not start with 'home' activity: education
#  Person pid:2021004768-3 hid:2021002029 plan does not start with 'home' activity: medical
#  Person pid:2021004791-2 hid:2021002041 plan does not start with 'home' activity: work
#  Person pid:2021004791-5 hid:2021002041 plan does not start with 'home' activity: work
#  Person pid:2021004791-7 hid:2021002041 plan does not start with 'home' activity: work
#  Person pid:2021004793-3 hid:2021002041 plan does not start with 'home' activity: visit
#  Person pid:2021004793-6 hid:2021002041 plan does not start with 'home' activity: visit
# ...
#  Person pid:2021009994-1 hid:2021004367 plan does not start with 'home' activity: visit
#  Person pid:2021009998-1 hid:2021004369 plan does not start with 'home' activity: work
#  Person pid:2021009998-3 hid:2021004369 plan does not start with 'home' activity: work
#  Person pid:2021009998-4 hid:2021004369 plan does not start with 'home' activity: work
#  Person pid:2021009998-5 hid:2021004369 plan does not start with 'home' activity: work
#  Person pid:2021009998-6 hid:2021004369 plan does not start with 'home' activity: work
#  Person pid:2021010005-2 hid:2021004372 plan does not start with 'home' activity: visit
#  Person pid:2021010006-1 hid:2021004372 plan does not start with 'home' activity: visit
#  Person pid:2021010006-4 hid:2021004372 plan does not start with 'home' activity: visit
#  Person pid:2021010006-5 hid:2021004372 plan does not start with 'home' activity: visit
#  Person pid:2021010012-1 hid:2021004375 plan does not start with 'home' activity: visit
#  Person pid:2021010013-1 hid:2021004375 plan does not start with 'home' activity: visit
#  Person pid:2021010048-4 hid:2021004389 plan does not start with 'home' activity: visit
#  Person pid:2021010079-5 hid:2021004403 plan does not start with 'home' activity: visit
#  Person pid:2021010079-6 hid:2021004403 plan does not start with 'home' activity: visit
#  Person pid:2021010087-1 hid:2021004406 plan does not start with 'home' activity: work
#  Person pid:2021010087-2 hid:2021004406 plan does not start with 'home' activity: work
#  Person pid:2021010087-3 hid:2021004406 plan does not start with 'home' activity: work
#  Person pid:2021010087-4 hid:2021004406 plan does not start with 'home' activity: work
#  Person pid:2021010087-7 hid:2021004406 plan does not start with 'home' activity: work
#  Person pid:2021010097-3 hid:2021004411 plan does not start with 'home' activity: other
#  Person pid:2021010098-4 hid:2021004411 plan does not start with 'home' activity: other
#  Person pid:2021010111-3 hid:2021004415 plan does not start with 'home' activity: visit
#  Person pid:2021010112-5 hid:2021004415 plan does not start with 'home' activity: visit
#  Person pid:2021010119-7 hid:2021004419 plan does not start with 'home' activity: escort
#  Person pid:2021010120-1 hid:2021004419 plan does not start with 'home' activity: work
#  Person pid:2021010120-2 hid:2021004419 plan does not start with 'home' activity: work
#  Person pid:2021010121-7 hid:2021004419 plan does not start with 'home' activity: escort
#  Person pid:2021010122-7 hid:2021004419 plan does not start with 'home' activity: visit
#  Person pid:2021010133-4 hid:2021004423 plan does not start with 'home' activity: visit
#  Person pid:2021010135-3 hid:2021004423 plan does not start with 'home' activity: visit
#  Person pid:2021010135-4 hid:2021004423 plan does not start with 'home' activity: visit
#  Person pid:2021010141-1 hid:2021004425 plan does not start with 'home' activity: visit
#  Person pid:2021010141-2 hid:2021004425 plan does not start with 'home' activity: education
#  Person pid:2021010141-3 hid:2021004425 plan does not start with 'home' activity: visit
#  Person pid:2021010141-5 hid:2021004425 plan does not start with 'home' activity: education
#  Person pid:2021010141-6 hid:2021004425 plan does not start with 'home' activity: visit
#  Person pid:2021010144-2 hid:2021004427 plan does not start with 'home' activity: visit
#  Person pid:2021010145-4 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010145-5 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010146-2 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010146-3 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010147-4 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010147-5 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010148-4 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010148-5 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010149-4 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010149-5 hid:2021004428 plan does not start with 'home' activity: visit
#  Person pid:2021010152-2 hid:2021004430 plan does not start with 'home' activity: visit
#  Person pid:2021010152-4 hid:2021004430 plan does not start with 'home' activity: visit
#  Person pid:2021010153-2 hid:2021004430 plan does not start with 'home' activity: work
#  Person pid:2021010166-6 hid:2021004437 plan does not start with 'home' activity: work
#  Person pid:2021010166-7 hid:2021004437 plan does not start with 'home' activity: work
#  Person pid:2021010172-2 hid:2021004440 plan does not start with 'home' activity: visit
#  Person pid:2021010173-2 hid:2021004441 plan does not start with 'home' activity: other
#  Person pid:2021010177-2 hid:2021004443 plan does not start with 'home' activity: other
#  Person pid:2021010178-3 hid:2021004444 plan does not start with 'home' activity: visit
#  Person pid:2021010178-4 hid:2021004444 plan does not start with 'home' activity: visit
#  Person pid:2021010179-4 hid:2021004445 plan does not start with 'home' activity: visit
#  Person pid:2021010180-2 hid:2021004445 plan does not start with 'home' activity: work
#  Person pid:2021010180-5 hid:2021004445 plan does not start with 'home' activity: work
#  Person pid:2021010196-3 hid:2021004453 plan does not start with 'home' activity: visit
#  Person pid:2021010255-5 hid:2021004488 plan does not start with 'home' activity: work
#  Person pid:2021010291-2 hid:2021004505 plan does not start with 'home' activity: visit
#  Person pid:2021010291-3 hid:2021004505 plan does not start with 'home' activity: work
#  Person pid:2021010291-4 hid:2021004505 plan does not start with 'home' activity: work
#  Person pid:2021010291-5 hid:2021004505 plan does not start with 'home' activity: visit
#  Person pid:2021010303-5 hid:2021004510 plan does not start with 'home' activity: visit
#  Person pid:2021010307-3 hid:2021004512 plan does not start with 'home' activity: shop
#  Person pid:2021010307-4 hid:2021004512 plan does not start with 'home' activity: work
#  Person pid:2021010311-2 hid:2021004514 plan does not start with 'home' activity: work
#  Person pid:2021010311-3 hid:2021004514 plan does not start with 'home' activity: work
#  Person pid:2021010312-2 hid:2021004514 plan does not start with 'home' activity: work
#  Person pid:2021010319-1 hid:2021004518 plan does not start with 'home' activity: work
#  Person pid:2021010319-2 hid:2021004518 plan does not start with 'home' activity: work
#  Person pid:2021010319-3 hid:2021004518 plan does not start with 'home' activity: work
#  Person pid:2021010319-5 hid:2021004518 plan does not start with 'home' activity: work
#  Person pid:2021010319-6 hid:2021004518 plan does not start with 'home' activity: work
#  Person pid:2021010319-7 hid:2021004518 plan does not start with 'home' activity: work
#  Person pid:2021010320-2 hid:2021004518 plan does not start with 'home' activity: visit
#  Person pid:2021010322-1 hid:2021004519 plan does not start with 'home' activity: work
#  Person pid:2021010341-4 hid:2021004530 plan does not start with 'home' activity: work
#  Person pid:2021010341-5 hid:2021004530 plan does not start with 'home' activity: work
#  Person pid:2021010341-6 hid:2021004530 plan does not start with 'home' activity: work
#  Person pid:2021010341-7 hid:2021004530 plan does not start with 'home' activity: work
#  Person pid:2021010371-5 hid:2021004541 plan does not start with 'home' activity: work
#  Person pid:2021010383-4 hid:2021004546 plan does not start with 'home' activity: other
#  Person pid:2021010397-6 hid:2021004551 plan does not start with 'home' activity: work
#  Person pid:2021010420-1 hid:2021004562 plan does not start with 'home' activity: work
#  Person pid:2021010420-2 hid:2021004562 plan does not start with 'home' activity: work
#  Person pid:2021010420-3 hid:2021004562 plan does not start with 'home' activity: work
#  Person pid:2021010420-4 hid:2021004562 plan does not start with 'home' activity: other
#  Person pid:2021010420-7 hid:2021004562 plan does not start with 'home' activity: work
#  Person pid:2021010423-1 hid:2021004564 plan does not start with 'home' activity: work
#  Person pid:2021010423-3 hid:2021004564 plan does not start with 'home' activity: visit
#  Person pid:2021010432-2 hid:2021004568 plan does not start with 'home' activity: visit
#  Person pid:2021010449-3 hid:2021004575 plan does not start with 'home' activity: visit
#  Person pid:2021010460-3 hid:2021004580 plan does not start with 'home' activity: visit
#  Person pid:2021010461-3 hid:2021004580 plan does not start with 'home' activity: visit
#  Person pid:2021010462-2 hid:2021004581 plan does not start with 'home' activity: work
#  Person pid:2021010462-3 hid:2021004581 plan does not start with 'home' activity: work
#  Person pid:2021010547-3 hid:2021004616 plan does not start with 'home' activity: other
#  Person pid:2021010548-3 hid:2021004616 plan does not start with 'home' activity: other
#  Person pid:2021010549-6 hid:2021004617 plan does not start with 'home' activity: other
#  Person pid:2021010551-6 hid:2021004618 plan does not start with 'home' activity: visit
#  Person pid:2021010554-5 hid:2021004620 plan does not start with 'home' activity: other
#  Person pid:2021010566-5 hid:2021004626 plan does not start with 'home' activity: other
#  Person pid:2021010567-5 hid:2021004627 plan does not start with 'home' activity: visit
#  Person pid:2021010568-4 hid:2021004628 plan does not start with 'home' activity: escort
#  Person pid:2021010568-5 hid:2021004628 plan does not start with 'home' activity: escort
#  Person pid:2021010586-3 hid:2021004635 plan does not start with 'home' activity: work
#  Person pid:2021010586-4 hid:2021004635 plan does not start with 'home' activity: work
#  Person pid:2021010586-5 hid:2021004635 plan does not start with 'home' activity: work
#  Person pid:2021010586-6 hid:2021004635 plan does not start with 'home' activity: work
#  Person pid:2021010586-7 hid:2021004635 plan does not start with 'home' activity: work
#  Person pid:2021010628-3 hid:2021004651 plan does not start with 'home' activity: visit
#  Person pid:2021010629-3 hid:2021004651 plan does not start with 'home' activity: visit
#  Person pid:2021010630-3 hid:2021004652 plan does not start with 'home' activity: other
#  Person pid:2021010636-4 hid:2021004654 plan does not start with 'home' activity: escort
#  Person pid:2021010637-5 hid:2021004654 plan does not start with 'home' activity: escort
#  Person pid:2021010643-4 hid:2021004657 plan does not start with 'home' activity: work
#  Person pid:2021010654-2 hid:2021004662 plan does not start with 'home' activity: work
#  Person pid:2021010655-3 hid:2021004662 plan does not start with 'home' activity: visit
#  Person pid:2021010656-2 hid:2021004662 plan does not start with 'home' activity: visit
#  Person pid:2021010657-2 hid:2021004662 plan does not start with 'home' activity: visit
#  Person pid:2021010658-2 hid:2021004662 plan does not start with 'home' activity: visit
#  Person pid:2021010659-2 hid:2021004662 plan does not start with 'home' activity: visit
#  Person pid:2021010675-4 hid:2021004673 plan does not start with 'home' activity: visit
#  Person pid:2021010687-1 hid:2021004679 plan does not start with 'home' activity: visit
#  Person pid:2021010689-5 hid:2021004680 plan does not start with 'home' activity: visit
#  Person pid:2021010745-2 hid:2021004703 plan does not start with 'home' activity: work
#  Person pid:2021010745-4 hid:2021004703 plan does not start with 'home' activity: work
#  Person pid:2021010745-5 hid:2021004703 plan does not start with 'home' activity: work
#  Person pid:2021010745-6 hid:2021004703 plan does not start with 'home' activity: work
#  Person pid:2021010745-7 hid:2021004703 plan does not start with 'home' activity: work
#  Person pid:2021010750-3 hid:2021004707 plan does not start with 'home' activity: visit
#  Person pid:2021010751-3 hid:2021004708 plan does not start with 'home' activity: other
#  Person pid:2021010751-4 hid:2021004708 plan does not start with 'home' activity: other
#  Person pid:2021010763-2 hid:2021004714 plan does not start with 'home' activity: work
#  Person pid:2021010802-2 hid:2021004728 plan does not start with 'home' activity: work
#  Person pid:2021010802-5 hid:2021004728 plan does not start with 'home' activity: work
#  Person pid:2021010808-2 hid:2021004729 plan does not start with 'home' activity: visit
#  Person pid:2021010808-3 hid:2021004729 plan does not start with 'home' activity: visit
#  Person pid:2021010824-6 hid:2021004737 plan does not start with 'home' activity: visit
#  Person pid:2021010824-7 hid:2021004737 plan does not start with 'home' activity: visit
#  Person pid:2021010840-1 hid:2021004743 plan does not start with 'home' activity: visit
#  Person pid:2021010841-3 hid:2021004743 plan does not start with 'home' activity: visit
#  Person pid:2021010838-3 hid:2021004743 plan does not start with 'home' activity: visit
#  Person pid:2021010839-2 hid:2021004743 plan does not start with 'home' activity: work
#  Person pid:2021010839-3 hid:2021004743 plan does not start with 'home' activity: work
#  Person pid:2021010839-4 hid:2021004743 plan does not start with 'home' activity: work
#  Person pid:2021010839-5 hid:2021004743 plan does not start with 'home' activity: visit
#  Person pid:2021010860-2 hid:2021004751 plan does not start with 'home' activity: visit
#  Person pid:2021010865-5 hid:2021004754 plan does not start with 'home' activity: visit
#  Person pid:2021010865-6 hid:2021004754 plan does not start with 'home' activity: visit
#  Person pid:2021010905-3 hid:2021004771 plan does not start with 'home' activity: work
#  Person pid:2021010905-4 hid:2021004771 plan does not start with 'home' activity: work
#  Person pid:2021010917-2 hid:2021004776 plan does not start with 'home' activity: work
#  Person pid:2021010917-3 hid:2021004776 plan does not start with 'home' activity: work
#  Person pid:2021010917-4 hid:2021004776 plan does not start with 'home' activity: work
#  Person pid:2021010917-5 hid:2021004776 plan does not start with 'home' activity: work
#  Person pid:2021010924-5 hid:2021004779 plan does not start with 'home' activity: work
#  Person pid:2021010927-4 hid:2021004781 plan does not start with 'home' activity: work
#  Person pid:2021010929-1 hid:2021004782 plan does not start with 'home' activity: visit
#  Person pid:2021010929-2 hid:2021004782 plan does not start with 'home' activity: visit
#  Person pid:2021010937-4 hid:2021004785 plan does not start with 'home' activity: visit
#  Person pid:2021010937-5 hid:2021004785 plan does not start with 'home' activity: visit
#  Person pid:2021010938-3 hid:2021004785 plan does not start with 'home' activity: visit
#  Person pid:2021010938-4 hid:2021004785 plan does not start with 'home' activity: visit
#  Person pid:2021010967-2 hid:2021004796 plan does not start with 'home' activity: visit
#  Person pid:2021010975-4 hid:2021004800 plan does not start with 'home' activity: other
#  Person pid:2021010977-7 hid:2021004801 plan does not start with 'home' activity: other
#  Person pid:2021010978-5 hid:2021004802 plan does not start with 'home' activity: other
#  Person pid:2021010979-3 hid:2021004802 plan does not start with 'home' activity: other
#  Person pid:2021010979-5 hid:2021004802 plan does not start with 'home' activity: visit
#  Person pid:2021010983-2 hid:2021004804 plan does not start with 'home' activity: shop
#  Person pid:2021010983-3 hid:2021004804 plan does not start with 'home' activity: shop
#  Person pid:2021010988-3 hid:2021004808 plan does not start with 'home' activity: work
#  Person pid:2021011013-1 hid:2021004819 plan does not start with 'home' activity: visit
#  Person pid:2021011013-3 hid:2021004819 plan does not start with 'home' activity: visit
# {'num_households': 4276, 'num_people': 39850, 'num_activities': 145055, 'num_legs': 105205}
# {'num_households': 4276, 'num_people': 39850, 'num_activities': 144965, 'num_legs': 105115}

# %%
def dt_to_min(dt) -> int:
    h, m, s = datetime_to_matsim_time(dt).split(":")
    return (int(h) * 60) + int(m)


def pam_to_schedules(population: Population) -> pd.DataFrame:
    """write trace of population. Ignoring trips."""
    record = []
    for uid, (hid, pid, person) in enumerate(population.people()):
        for i in range(0, len(person.plan) - 1, 2):
            record.append(
                [
                    uid,
                    hid,
                    person.plan[i].act,
                    dt_to_min(person.plan[i].start_time),
                    dt_to_min(person.plan[i + 1].end_time),
                ]
            )
        record.append(
            [
                uid,
                hid,
                person.plan[-1].act,
                dt_to_min(person.plan[-1].start_time),
                dt_to_min(person.plan[-1].end_time),
            ]
        )

    df = pd.DataFrame(record, columns=["pid", "hid", "act", "start", "end"])
    df["duration"] = df.end - df.start
    return df


schedules = pam_to_schedules(population=pam_population)

attributes = pd.DataFrame(
    [
        {**{"pid": pid}, **p.attributes}
        for pid, (_, _, p) in enumerate(pam_population.people())
    ]
).drop(["iid", "year"], axis=1)
attributes.describe()

assert set(schedules.pid).issubset(set(attributes.pid))

schedules.to_csv(schedules_path, index=False)
attributes.to_csv(attributes_path, index=False)

schedules.describe()
# Out:
#                  pid           hid          start            end  \
# count  144965.000000  1.449650e+05  144965.000000  144965.000000
# mean    20236.441431  2.021003e+09     591.398731     987.246004
# std     11462.828042  1.373046e+03     415.282364     342.894915
# min         0.000000  2.021000e+09       0.000000       3.000000
# 25%     10352.000000  2.021001e+09       0.000000     692.000000
# 50%     20353.000000  2.021003e+09     670.000000     950.000000
# 75%     30258.000000  2.021004e+09     930.000000    1440.000000
# max     39849.000000  2.021005e+09    1440.000000    1440.000000
#
#             duration
# count  144965.000000
# mean      395.847273
# std       282.762721
# min         0.000000
# 25%       105.000000
# 50%       420.000000
# 75%       590.000000
# max      1440.000000

# %%
_ = times_distributions_plot(schedules, ys={})

# %%
_ = joint_time_distributions_plot(schedules, ys={})

# %%
_ = sequence_prob_plot(schedules, ys={}, figsize=(8, 6))

# %%
def pam_to_population_home_based_plans_only(
    population: Population,
) -> pd.DataFrame:
    """Convert population to trace. Only home-based plans are included."""
    record = []
    for uid, (hid, pid, person) in enumerate(population.people()):
        person_record = []
        for i in range(0, len(person.plan) - 1, 2):
            person_record.append(
                [
                    uid,
                    hid,
                    person.plan[i].act,
                    dt_to_min(person.plan[i].start_time),
                    dt_to_min(person.plan[i + 1].end_time),
                ]
            )
        person_record.append(
            [
                uid,
                hid,
                person.plan[-1].act,
                dt_to_min(person.plan[-1].start_time),
                dt_to_min(person.plan[-1].end_time),
            ]
        )
        if (person_record[0][2] == "home") and (person_record[-1][2] == "home"):
            record.extend(person_record)

    df = pd.DataFrame(record, columns=["pid", "hid", "act", "start", "end"])
    df["duration"] = df.end - df.start
    return df


home_schedules = pam_to_population_home_based_plans_only(pam_population)

home_attributes = pd.DataFrame(
    [
        {**{"pid": pid}, **p.attributes}
        for pid, (_, _, p) in enumerate(pam_population.people())
    ]
).drop(["iid", "year"], axis=1)
attributes.describe()

assert set(home_schedules.pid).issubset(set(home_attributes.pid))

home_schedules.to_csv(home_schedules_path, index=False)
home_attributes.to_csv(home_attributes_path, index=False)
